# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
from statsmodels.stats.multitest import multipletests

# %%
df = pd.read_csv("yRL167_pRL1007.csv")
df
# Out:
#       date  strain plasmid  name  number  dots  cells
# 0   191124     167   empty   167       1    10     69
# 1   191124     167   empty   167       1    13     52
# 2   191124     167   empty   167       1     6     63
# 3   191124     167   empty   167       2     7     58
# 4   191124     167   empty   167       2     8     48
# 5   191124     167   empty   167       2     4     41
# 6   191124     167   empty   167       3     9     89
# 7   191124     167   empty   167       3     8     69
# 8   191124     167   empty   167       3    12     63
# 9   191124     392   empty   392       1     1     59
# 10  191124     392   empty   392       1     1     53
# 11  191124     392   empty   392       2     0     55
# 12  191124     392   empty   392       2     0     52
# 13  191124     392   empty   392       3     0     65
# 14  191124     392   empty   392       3     2     63
# 15  191124     392    1007  1007       1     5     61
# 16  191124     392    1007  1007       1     3     55
# 17  191124     392    1007  1007       1     5     71
# 18  191124     392    1007  1007       2     9     58
# 19  191124     392    1007  1007       2    11     60
# 20  191124     392    1007  1007       3     7     52
# 21  191124     392    1007  1007       3    11     62

# %%
# calculate SE / cells (%)
df_number = df.groupby(["name", "number"], as_index=False).sum()
df_number["SE"] = df_number["dots"] * 100 / df_number["cells"]
df_number
# Out:
#    name  number    date  strain          plasmid  dots  cells         SE
# 0   167       1  573372     501  emptyemptyempty    29    184  15.760870
# 1   167       2  573372     501  emptyemptyempty    19    147  12.925170
# 2   167       3  573372     501  emptyemptyempty    29    221  13.122172
# 3   392       1  382248     784       emptyempty     2    112   1.785714
# 4   392       2  382248     784       emptyempty     0    107   0.000000
# 5   392       3  382248     784       emptyempty     2    128   1.562500
# 6  1007       1  573372    1176     100710071007    13    187   6.951872
# 7  1007       2  382248     784         10071007    20    118  16.949153
# 8  1007       3  382248     784         10071007    18    114  15.789474

# %%
df['name'].unique()
# Out:
# array([ 167,  392, 1007], dtype=int64)

# %%
# calculate average and sem of different condition
# WT vs atg18D vs atg18D + pRL1007 (pRS416-3FLAG-ATG18)
SE_mean = df_number.groupby('name')["SE"].mean().values
SE_sem = df_number.groupby("name")["SE"].std().values / np.sqrt(3)
print(f"strain: {df['name'].unique()}, SE mean (%): {SE_mean}")
print(f"strain: {df['name'].unique()}, SE (%) SEM: {SE_mean}")
# Out:
# strain: [ 167  392 1007], SE mean (%): [13.93607053  1.11607143 13.23016596]
# strain: [ 167  392 1007], SE (%) SEM: [13.93607053  1.11607143 13.23016596]

# %% [markdown]
# ## Welth's t-test collected with Holm-sidak

# %%
WT_SE = df_number[df_number["name"] == 167]["SE"]
atg18_SE = df_number[df_number["name"] == 392]["SE"]
pRL1007_SE = df_number[df_number["name"] == 1007]["SE"]
statistic, atg18_pvalue = stats.ttest_ind(WT_SE, atg18_SE, equal_var=False)
statistic, pRL1007_pvalue = stats.ttest_ind(WT_SE, pRL1007_SE, equal_var=False)
print(f'p value wt vs atg18D: {atg18_pvalue}')
print(f'p value wt vs atg18D + pRL1007: {pRL1007_pvalue}')
# Out:
# p value wt vs atg18D: 0.0007635614545760652
# p value wt vs atg18D + pRL1007: 0.8472848010929684

# %%
multipletests(pvals=[atg18_pvalue, pRL1007_pvalue], alpha=0.05, method="holm-sidak")
# Out:
# (array([ True, False]),
#  array([0.00152654, 0.8472848 ]),
#  0.025320565519103666,
#  0.025)

# %% [markdown]
# ## figure

# %%
y = -6
fontsize = 15
fig, ax = plt.subplots(figsize = (3, 2), dpi=100)
sns.swarmplot(x="name", y="SE", data=df_number, size=6, color="black")
ax.errorbar(x=[0, 1, 2], y=SE_mean, yerr=SE_sem, \
            capsize=5, fmt='_', ecolor='k', ms=20, mec='k')
# label of each strains
ax.text(0, y, "WT", ha="center", va='center', fontsize=fontsize-1.5)
ax.text(1, y, "atg18Δ", ha="center", va='center', fontstyle="italic", fontsize=fontsize-1.5)
ax.text(1.6, y, "atg18Δ\n+3FLAG-ATG18", ha='left', va='center', fontstyle="italic", fontsize=fontsize-1.5)
# figure frame
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# x and y axis
ax.set_xlim(-0.5, 2.5)
ax.set_ylim(-1, 25)
ax.set_xticklabels("")
ax.set_xlabel("")
ax.set_yticks([0, 10, 20])
ax.set_yticklabels(["0", "10", "20"], fontsize=fontsize)
ax.set_ylabel("% of cells\n with puncta", fontsize=fontsize, loc="center")
y_p = 19
ax.plot([0, 1], [y_p, y_p], color='k', lw=1)
ax.text(0.5, y_p+1, f'p = {atg18_pvalue:.3f}$^*$', ha='center', fontsize=fontsize-2)
y_p2 = 24
ax.plot([0, 2], [y_p2, y_p2], color='k', lw=1)
ax.text(1.5, y_p2+1, f'p = {pRL1007_pvalue:.3f}', ha='center', fontsize=fontsize-2)

fig.savefig("output.jpg", bbox_inches="tight")
plt.show()
