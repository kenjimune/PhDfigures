# %%
from glob import glob
import os

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns

# %%
order_dict = {
    'no_bud' : 0,
    'small_mother' : 1,
    'small_daughter' : 2,
    'large_mother' : 3,
    'large_daughter' : 4,
}

# %%
csv_files = glob('./*.csv')
dataframes = []
count = 1
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    df_count = df.groupby(['5class'], as_index=False).count()
    cell_count = {}
    for _, row in df_count.iterrows():
        if row['5class']=='-':
            pass
        else:
            cell_count[row['5class']] = row['SE']
    df_SE = df[df['SE']==1.0].groupby(['5class', 'SE'], as_index=False).count()
    df_SE = df_SE[df_SE['5class']!='-']
    df_SE['count'] = df_SE.apply(lambda row: cell_count[row['5class']], axis=1)
    df_SE['SE_cell'] = df_SE['ratio'] / df_SE['count'] * 100
    df_SE['relative'] = df_SE['SE_cell'].apply\
    (lambda x: x / df_SE[df_SE['5class']=='no_bud']['SE_cell'])
    df_SE['number'] = count
    df_SE['order'] = df_SE['5class'].apply(lambda x: order_dict[x])
    dataframes.append(df_SE)
    count += 1
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df
# Out:
#             5class   SE  Area   X   Y  Perim.  classification  reference  \
# 0   large_daughter  1.0    18  18  18      18              18         18
# 1     large_mother  1.0    20  20  20      20              20         20
# 2           no_bud  1.0     7   7   7       7               7          7
# 3   small_daughter  1.0     2   2   2       2               2          2
# 4     small_mother  1.0     8   8   8       8               8          8
# 5   large_daughter  1.0    32  32  32      32              32         32
# 6     large_mother  1.0    23  23  23      23              23         23
# 7           no_bud  1.0    13  13  13      13              13         13
# 8   small_daughter  1.0     2   2   2       2               2          2
# 9     small_mother  1.0    12  12  12      12              12         12
# 10  large_daughter  1.0    29  29  29      29              29         29
# 11    large_mother  1.0    21  21  21      21              21         21
# 12          no_bud  1.0    10  10  10      10              10         10
# 13  small_daughter  1.0     1   1   1       1               1          1
# 14    small_mother  1.0    11  11  11      11              11         11
#
#     ref_peri  ratio  count    SE_cell  relative  number  order
# 0         18     18    150  12.000000  0.805714       1      4
# 1         20     20    148  13.513514  0.907336       1      3
# 2          7      7     47  14.893617  1.000000       1      0
# 3          2      2     40   5.000000  0.335714       1      2
# 4          8      8     40  20.000000  1.342857       1      1
# 5         32     32    214  14.953271  0.793674       2      4
# 6         23     23    218  10.550459  0.559986       2      3
# 7         13     13     69  18.840580  1.000000       2      0
# 8          2      2     57   3.508772  0.186235       2      2
# 9         12     12     60  20.000000  1.061538       2      1
# 10        29     29    268  10.820896  0.811567       3      4
# 11        21     21    269   7.806691  0.585502       3      3
# 12        10     10     75  13.333333  1.000000       3      0
# 13         1      1     92   1.086957  0.081522       3      2
# 14        11     11     93  11.827957  0.887097       3      1

# %%
df_agg = combined_df.groupby('5class').mean()
df_agg['SE_cell_sem'] = combined_df.groupby('5class').std()['SE_cell'] / np.sqrt(3)
df_agg
# Out:
#                  SE       Area          X          Y     Perim.  \
# 5class
# large_daughter  1.0  26.333333  26.333333  26.333333  26.333333
# large_mother    1.0  21.333333  21.333333  21.333333  21.333333
# no_bud          1.0  10.000000  10.000000  10.000000  10.000000
# small_daughter  1.0   1.666667   1.666667   1.666667   1.666667
# small_mother    1.0  10.333333  10.333333  10.333333  10.333333
#
#                 classification  reference   ref_peri      ratio       count  \
# 5class
# large_daughter       26.333333  26.333333  26.333333  26.333333  210.666667
# large_mother         21.333333  21.333333  21.333333  21.333333  211.666667
# no_bud               10.000000  10.000000  10.000000  10.000000   63.666667
# small_daughter        1.666667   1.666667   1.666667   1.666667   63.000000
# small_mother         10.333333  10.333333  10.333333  10.333333   64.333333
#
#                   SE_cell  relative  number  order  SE_cell_sem
# 5class
# large_daughter  12.591389  0.803652     2.0    4.0     1.229016
# large_mother    10.623555  0.684275     2.0    3.0     1.647823
# no_bud          15.689177  1.000000     2.0    0.0     1.638813
# small_daughter   3.198576  0.201157     2.0    2.0     1.140196
# small_mother    17.275986  1.097164     2.0    1.0     2.724014

# %%
combined_df.groupby('number').sum()
# Out:
#                                                    5class   SE  Area   X   Y  \
# number
# 1       large_daughterlarge_motherno_budsmall_daughter...  5.0    55  55  55
# 2       large_daughterlarge_motherno_budsmall_daughter...  5.0    82  82  82
# 3       large_daughterlarge_motherno_budsmall_daughter...  5.0    72  72  72
#
#         Perim.  classification  reference  ref_peri  ratio  count    SE_cell  \
# number
# 1           55              55         55        55     55    425  65.407131
# 2           82              82         82        82     82    618  67.853081
# 3           72              72         72        72     72    797  44.875834
#
#         relative  order
# number
# 1       4.391622     10
# 2       3.601433     10
# 3       3.365688     10

# %% [markdown]
# ## Tukey

# %%
SE_nobud = combined_df[combined_df['5class']=='no_bud']['SE_cell']
SE_sm = combined_df[combined_df['5class']=='small_mother']['SE_cell']
SE_sd = combined_df[combined_df['5class']=='small_daughter']['SE_cell']
SE_lm = combined_df[combined_df['5class']=='large_mother']['SE_cell']
SE_ld = combined_df[combined_df['5class']=='large_daughter']['SE_cell']

# %%
res = stats.tukey_hsd(SE_nobud, SE_sm, SE_sd, SE_lm, SE_ld)
print(res)
# Out:
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -1.587     0.966    -9.816     6.643
#  (0 - 2)     12.491     0.004     4.261    20.720
#  (0 - 3)      5.066     0.321    -3.164    13.295
#  (0 - 4)      3.098     0.731    -5.132    11.327
#  (1 - 0)      1.587     0.966    -6.643     9.816
#  (1 - 2)     14.077     0.002     5.848    22.307
#  (1 - 3)      6.652     0.131    -1.577    14.882
#  (1 - 4)      4.685     0.388    -3.545    12.914
#  (2 - 0)    -12.491     0.004   -20.720    -4.261
#  (2 - 1)    -14.077     0.002   -22.307    -5.848
#  (2 - 3)     -7.425     0.082   -15.654     0.805
#  (2 - 4)     -9.393     0.024   -17.622    -1.163
#  (3 - 0)     -5.066     0.321   -13.295     3.164
#  (3 - 1)     -6.652     0.131   -14.882     1.577
#  (3 - 2)      7.425     0.082    -0.805    15.654
#  (3 - 4)     -1.968     0.929   -10.197     6.262
#  (4 - 0)     -3.098     0.731   -11.327     5.132
#  (4 - 1)     -4.685     0.388   -12.914     3.545
#  (4 - 2)      9.393     0.024     1.163    17.622
#  (4 - 3)      1.968     0.929    -6.262    10.197

# %%
df_stats = combined_df[['5class', 'count', 'SE_cell', 'relative', 'number', 'order']]
df_agg = df_stats.groupby(['5class'], as_index=False).mean()
df_agg['relative_sem'] = df_stats.groupby('5class', as_index=False)\
                         .std()['relative'].values / np.sqrt(3)
df_agg['SE_cell_sem'] = df_stats.groupby('5class', as_index=False)\
                         .std()['SE_cell'].values / np.sqrt(3)
df_agg = df_agg.sort_values('order')
df_agg
# Out:
#            5class       count    SE_cell  relative  number  order  \
# 2          no_bud   63.666667  15.689177  1.000000     2.0    0.0
# 4    small_mother   64.333333  17.275986  1.097164     2.0    1.0
# 3  small_daughter   63.000000   3.198576  0.201157     2.0    2.0
# 1    large_mother  211.666667  10.623555  0.684275     2.0    3.0
# 0  large_daughter  210.666667  12.591389  0.803652     2.0    4.0
#
#    relative_sem  SE_cell_sem
# 2      0.000000     1.638813
# 4      0.132767     2.724014
# 3      0.073757     1.140196
# 1      0.111774     1.647823
# 0      0.005267     1.229016

# %%
fontsize = 15

fig, ax = plt.subplots(figsize = (5, 2), dpi=100)
sns.swarmplot(x='order', y='SE_cell', hue='number', palette='deep', data=combined_df)
ax.errorbar(x='order', y='SE_cell', yerr='SE_cell_sem', data=df_agg, capsize=5, fmt='_', ecolor='k', ms=20, mfc='None', mec='k')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.set_xticklabels("")
ax.set_xlabel("")
y = -4
y2 = y * 2
ax.text(0, y, "-", ha="center", fontsize=fontsize)
ax.text(0, y2, "No", ha="center", fontsize=fontsize)
ax.text(-0.5, y2, "Bud:", ha="center", fontsize=fontsize)
ax.text(1, y, "M", ha="center", fontsize=fontsize)
ax.text(2, y, "D", ha="center", fontsize=fontsize)
ax.text(3, y, "M", ha="center", fontsize=fontsize)
ax.text(4, y, "D", ha="center", fontsize=fontsize)
ax.plot([0.9, 2.1], [-5, -5], color="black", linewidth=1, clip_on=False)
ax.text(1.5, y2, "Small", ha="center", fontsize=fontsize)
ax.plot([2.9, 4.1], [-5, -5], color="black", linewidth=1, clip_on=False)
ax.text(3.5, y2, "Large", ha="center", fontsize=fontsize)
ax.plot([-0.1, 4.1], [-9, -9], color="black", linewidth=1, clip_on=False)
ax.text(2, y*3, "Steady-state", ha="center", fontsize=fontsize)

ax.plot([2, 4], [18, 18], color='k', lw=1)
ax.text(3, 19, 'p = 0.024$^*$', ha='center', fontsize=fontsize-2)

ax.set_ylim(0, 22)
ax.set_yticks([0, 10, 20])
ax.set_yticklabels(["0", "10", "20"], fontsize=fontsize)
ax.set_ylabel("% of cells with\n Tor1 puncta", fontsize=fontsize, loc="center")
ax.legend().remove()

fig.savefig("output.jpg", bbox_inches="tight")
plt.show()
